# %%
paragraph = """Dr. A.P.J. Abdul Kalam, the 11th President of India, delivered numerous speeches, particularly focusing on inspiring youth and advocating for India's development. His speeches often emphasized the importance of dreaming, courage, and a positive attitude in achieving one's goals and building a developed nation. He encouraged young people to believe in their potential and work towards transforming their thoughts into action.
"""

paragraph
# Out:
# "Dr. A.P.J. Abdul Kalam, the 11th President of India, delivered numerous speeches, particularly focusing on inspiring youth and advocating for India's development. His speeches often emphasized the importance of dreaming, courage, and a positive attitude in achieving one's goals and building a developed nation. He encouraged young people to believe in their potential and work towards transforming their thoughts into action.\n"

# %%
import nltk
from nltk.corpus import stopwords
sentence = nltk.sent_tokenize(paragraph)
sentence
# Out:
# ['Dr. A.P.J.',
#  "Abdul Kalam, the 11th President of India, delivered numerous speeches, particularly focusing on inspiring youth and advocating for India's development.",
#  "His speeches often emphasized the importance of dreaming, courage, and a positive attitude in achieving one's goals and building a developed nation.",
#  'He encouraged young people to believe in their potential and work towards transforming their thoughts into action.']

# %%
nltk.download('stopwords')
nltk.download('all')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gumma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\gumma\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\gumma\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\gumma\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\gumma\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# ...

# %%
for i in range(len(sentence)):
    words = nltk.word_tokenize(sentence[i])
    words = [word for word in words if word not in set(stopwords.words('english'))]
    postag = nltk.pos_tag(words)
    print(postag)
# Out:
# [('Dr.', 'NNP'), ('A.P.J', 'NNP'), ('.', '.')]
# [('Abdul', 'NNP'), ('Kalam', 'NNP'), (',', ','), ('11th', 'CD'), ('President', 'NNP'), ('India', 'NNP'), (',', ','), ('delivered', 'VBD'), ('numerous', 'JJ'), ('speeches', 'NNS'), (',', ','), ('particularly', 'RB'), ('focusing', 'VBG'), ('inspiring', 'VBG'), ('youth', 'NN'), ('advocating', 'VBG'), ('India', 'NNP'), ("'s", 'POS'), ('development', 'NN'), ('.', '.')]
# [('His', 'PRP$'), ('speeches', 'NNS'), ('often', 'RB'), ('emphasized', 'VBD'), ('importance', 'NN'), ('dreaming', 'NN'), (',', ','), ('courage', 'NN'), (',', ','), ('positive', 'JJ'), ('attitude', 'NN'), ('achieving', 'VBG'), ('one', 'CD'), ("'s", 'POS'), ('goals', 'NNS'), ('building', 'VBG'), ('developed', 'JJ'), ('nation', 'NN'), ('.', '.')]
# [('He', 'PRP'), ('encouraged', 'VBD'), ('young', 'JJ'), ('people', 'NNS'), ('believe', 'VBP'), ('potential', 'JJ'), ('work', 'NN'), ('towards', 'NNS'), ('transforming', 'VBG'), ('thoughts', 'NNS'), ('action', 'NN'), ('.', '.')]

# %%
nltk.download("stopwords")
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re

# %%
vectorizer = CountVectorizer(binary=True)
X = vectorizer.fit_transform(df['cleaned_review'])
y = df['sentiment'].apply(lambda x :1 if x =='positive' else )
print("TF-IDF Matrix Shape:", X.shape)
print("Sample TD-IDF Row: ", X[0][:10])
